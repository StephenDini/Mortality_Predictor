# %% [markdown]
# # Alcohol Rate (2015) vs Mortality

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# read cleaned data CSV file
file_path = Path('./cleaned_data/data_by_country.csv')
df = pd.read_csv(file_path)
#df = pd.read_csv(file_path, index_col=0)
df.head(10)
# Out:
#    Unnamed: 0              Country  Literacy_Rate  Buddhists  Christians  \
# 0           0              Albania           96.8        1.0        18.0
# 1           1              Algeria           72.6        1.0         1.0
# 2           2               Angola           70.4        1.0        90.5
# 3           3  Antigua and Barbuda           99.0        1.0        93.0
# 4           4            Argentina           97.9        1.0        85.2
# 5           5              Armenia           99.6        1.0        98.5
# 6           6            Australia           99.0        2.7        67.3
# 7           7              Austria           98.0        1.0        80.4
# 8           8           Azerbaijan           99.8        1.0         3.0
# 9           9              Bahrain           94.6        2.5        14.5
#
#    Folk_Religions  Hindus  Jews  Muslims  Other_Religions  ...  \
# 0             1.0     1.0   1.0     80.3              1.0  ...
# ...

# %%
# Filter the DataFrame down only to those columns to chart
am = df[["alcohol_rate_2015","mortality_rate"]]


am.head()
# Out:
#    alcohol_rate_2015  mortality_rate
# 0               6.74            9.22
# 1               0.93            9.65
# 2               7.96           23.98
# 3               5.89           12.19
# 4               9.55           11.27

# %%
#scatter plot
x = am["mortality_rate"]
y = am["alcohol_rate_2015"]

plt.figure(figsize=(20, 12))
plt.scatter(x, y, s=75)

# Incorporate the other graph properties
plt.title("Alcohol vs Mortality Rate (2015)", fontsize=20)
plt.ylabel("Alcohol Rate (%)", fontsize=14)
plt.xlabel("Mortality Rate(%)", fontsize=14)

# Add correlation line
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color='r')

# Save the figure.
plt.savefig("./docs/pictures/Alcohol_vs_mortality.png")

# %% [markdown]
# # GDP (2015) vs Mortality

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# read cleaned data CSV file
file_path = Path('./cleaned_data/data_by_country.csv')
df = pd.read_csv(file_path)
#df = pd.read_csv(file_path, index_col=0)
df.head(10)
# Out:
#    Unnamed: 0              Country  Literacy_Rate  Buddhists  Christians  \
# 0           0              Albania           96.8        1.0        18.0
# 1           1              Algeria           72.6        1.0         1.0
# 2           2               Angola           70.4        1.0        90.5
# 3           3  Antigua and Barbuda           99.0        1.0        93.0
# 4           4            Argentina           97.9        1.0        85.2
# 5           5              Armenia           99.6        1.0        98.5
# 6           6            Australia           99.0        2.7        67.3
# 7           7              Austria           98.0        1.0        80.4
# 8           8           Azerbaijan           99.8        1.0         3.0
# 9           9              Bahrain           94.6        2.5        14.5
#
#    Folk_Religions  Hindus  Jews  Muslims  Other_Religions  ...  \
# 0             1.0     1.0   1.0     80.3              1.0  ...
# ...

# %%
# Filter the DataFrame down only to those columns to chart
gdp_m = df[["gpd_2015","mortality_rate"]]


gdp_m.head()
# Out:
#        gpd_2015  mortality_rate
# 0  1.138685e+10            9.22
# 1  1.659793e+11            9.65
# 2  8.721929e+10           23.98
# 3  1.336693e+09           12.19
# 4  5.947493e+11           11.27

# %%
#scatter plot
x = gdp_m["mortality_rate"]
y = gdp_m["gpd_2015"]

plt.figure(figsize=(20, 12))
plt.scatter(x, y, s=75)

# Incorporate the other graph properties
plt.title("GDP vs Mortality Rate (2015)", fontsize=24)
plt.ylabel("GDP ($)", fontsize=18)
plt.xlabel("Mortality Rate(%)", fontsize=18)


# https://queirozf.com/entries/matplotlib-examples-number-formatting-for-axes-labels
# Format the labels
current_values = plt.gca().get_yticks()
# using format string '{:.0f}' here but you can choose others
plt.gca().set_yticklabels(['${:,.0f}'.format(x) for x in current_values])


# Add correlation line
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color='r')

# Save the figure.
plt.savefig("./docs/pictures/GDP_vs_mortality.png")
# Out:
# C:\Users\claud\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # Literacy v Mortality

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# read cleaned data CSV file
file_path = Path('./cleaned_data/data_by_country.csv')
df = pd.read_csv(file_path)
#df = pd.read_csv(file_path, index_col=0)
df.head(10)
# Out:
#    Unnamed: 0              Country  Literacy_Rate  Buddhists  Christians  \
# 0           0              Albania           96.8        1.0        18.0
# 1           1              Algeria           72.6        1.0         1.0
# 2           2               Angola           70.4        1.0        90.5
# 3           3  Antigua and Barbuda           99.0        1.0        93.0
# 4           4            Argentina           97.9        1.0        85.2
# 5           5              Armenia           99.6        1.0        98.5
# 6           6            Australia           99.0        2.7        67.3
# 7           7              Austria           98.0        1.0        80.4
# 8           8           Azerbaijan           99.8        1.0         3.0
# 9           9              Bahrain           94.6        2.5        14.5
#
#    Folk_Religions  Hindus  Jews  Muslims  Other_Religions  ...  \
# 0             1.0     1.0   1.0     80.3              1.0  ...
# ...

# %%
# Filter the DataFrame down only to those columns to chart
lit_m = df[["Literacy_Rate","mortality_rate"]]


lit_m.head()
# Out:
#    Literacy_Rate  mortality_rate
# 0           96.8            9.22
# 1           72.6            9.65
# 2           70.4           23.98
# 3           99.0           12.19
# 4           97.9           11.27

# %%
#scatter plot
x = lit_m["mortality_rate"]
y = lit_m["Literacy_Rate"]

plt.figure(figsize=(20, 12))
plt.scatter(x, y, s=75)

# Incorporate the other graph properties
plt.title("Literacy vs Mortality Rate (2015)", fontsize=24)
plt.ylabel("Literacy (%)", fontsize=18)
plt.xlabel("Mortality Rate(%)", fontsize=18)


# https://queirozf.com/entries/matplotlib-examples-number-formatting-for-axes-labels
# Format the labels
current_values = plt.gca().get_yticks()
# using format string '{:.0f}' here but you can choose others
plt.gca().set_yticklabels(['{:,.0f}%'.format(x) for x in current_values])


# Add correlation line
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color='r')

# Save the figure.
plt.savefig("./docs/pictures/GDP_vs_mortality.png")
# Out:
# C:\Users\claud\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
