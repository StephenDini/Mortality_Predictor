# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# read cleaned data CSV file
file_path = Path('./cleaned_data/data_by_country.csv')
df = pd.read_csv(file_path)
#df = pd.read_csv(file_path, index_col=0)
df.head(10)
# Out:
#    Unnamed: 0              Country  Literacy_Rate  Buddhists  Christians  \
# 0           0              Albania           96.8        1.0        18.0
# 1           1              Algeria           72.6        1.0         1.0
# 2           2               Angola           70.4        1.0        90.5
# 3           3  Antigua and Barbuda           99.0        1.0        93.0
# 4           4            Argentina           97.9        1.0        85.2
# 5           5              Armenia           99.6        1.0        98.5
# 6           6            Australia           99.0        2.7        67.3
# 7           7              Austria           98.0        1.0        80.4
# 8           8           Azerbaijan           99.8        1.0         3.0
# 9           9              Bahrain           94.6        2.5        14.5
#
#    Folk_Religions  Hindus  Jews  Muslims  Other_Religions  ...  \
# 0             1.0     1.0   1.0     80.3              1.0  ...
# ...

# %%
# Filter the DataFrame down only to those columns to chart
am = df[["alcohol_rate_2015","mortality_rate"]]


am.head()
# Out:
#    alcohol_rate_2015  mortality_rate
# 0               6.74            9.22
# 1               0.93            9.65
# 2               7.96           23.98
# 3               5.89           12.19
# 4               9.55           11.27

# %%
#scatter plot
x = am["mortality_rate"]
y = am["alcohol_rate_2015"]

plt.figure(figsize=(20, 12))
plt.scatter(x, y, s=75)

# Incorporate the other graph properties
plt.title("Alcohol vs Mortality Rate (2015)", fontsize=20)
plt.ylabel("Alcohol Rate (%)", fontsize=14)
plt.xlabel("Mortality Rate(%)", fontsize=14)

# Add correlation line
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color='r')

# Save the figure.
plt.savefig("./docs/pictures/Alcohol_vs_mortality.png")
